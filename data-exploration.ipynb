# %%
import pickle as pkl
import sys

# %%
import sys

if not sys.warnoptions:
    import os, warnings
    warnings.simplefilter("default") # Change the filter in this process
    os.environ["PYTHONWARNINGS"] = "default" # Also affect subprocesses

# %%
df = pkl.load(open('all_courses_database_processed.plk', 'rb'))
# Out:
# /tmp/ipykernel_43137/2599300274.py:1: ResourceWarning: unclosed file <_io.BufferedReader name='all_courses_database_processed.plk'>
#   df = pkl.load(open('all_courses_database_processed.plk', 'rb'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
df
# Out:
#                                name     locality region postal_code  \
# 5234            Sequoyah State Park      Hulbert     OK       74441
# 1045                 China Peak DGC    Lakeshore     CA       93634
# 2812        Jamestown Reservoir DGC    Jamestown     ND       58401
# 5929          The Rock at Stonewall    Germanton     NC       27019
# 4881                  Riverbend DGC     Estacada     OR       97023
# ...                             ...          ...    ...         ...
# 6543                  Whitefish DGC    Whitefish     MT       59937
# 210   Augusta Disc Golf - Dragonfly      Augusta     ME       04330
# 6579           Wildflower Micro DGC   Cedar Park     TX       78613
# 2130       Gehringer Park Rec. Club      Concord     CA       94519
# 3064      L.L. Stub Stewart SP - PP       Buxton     OR       97064
#
#        latitude   longitude dgcr_id  year_established      tee_type  \
# 5234  35.896629  -95.242179    5795              2012         Grass
# 1045  37.236316 -119.158487    6299              2013        Rubber
# 2812  46.945319  -98.705633     575              2007      Concrete
# 5929  36.275930  -80.245988    8724              2016         Grass
# 4881  45.306640 -122.366399     416              1996      Concrete
# ...         ...         ...     ...               ...           ...
# 6543  48.390634 -114.345035   10746              2018          Dirt
# 210   44.294571  -69.768516    7681              2015  Patio Blocks
# 6579  30.465624  -97.844322    9712              2018        Rubber
# 2130  37.985154 -121.993522    8040              2015        Rubber
# 3064  45.739050 -123.199461    7605              2008         Brick
#
#           basket_type  ...  length  hours_to_play  multiple_layouts  hills  \
# 5234  Re-Tire Model A  ...   16400           7.14              True      2
# 1045       DISCatcher  ...   12962           5.84             False      2
# 2812       DISCatcher  ...   12666           5.73              True      1
# 5929  Dynamic Veteran  ...   12476           5.66              True      2
# 4881       DISCatcher  ...   12333           5.60              True      1
# ...               ...  ...     ...            ...               ...    ...
# 6543           Basket  ...     486           1.12             False      0
# 210        DISCatcher  ...     467           1.11             False      1
# 6579           Mach 5  ...     455           1.11             False      0
# 2130       DISCatcher  ...     427           1.10              True      0
# 3064       DISCatcher  ...     389           1.08             False      1
#
#       woods  par   sse  difficulty  rating  rating_count
# 5234      0   73  46.6   -1.466667    4.75             2
# 1045      1   84  92.7    0.322222    4.50             8
# 2812      0   82  70.3   -0.487500    4.43             7
# 5929      0   70  69.1   -0.050000    3.96            13
# 4881      1   89  81.3   -0.285185    4.62            75
# ...     ...  ...   ...         ...     ...           ...
# 6543      1   29  24.0   -0.555556    3.50             1
# 210       0   18  13.9   -0.455556    3.25             4
# 6579      0   11   7.5   -0.700000    2.63             4
# 2130      1   12   5.9   -1.525000    1.50             1
# 3064      2    9   4.1   -1.633333    1.75             4
#
# [4538 rows x 21 columns]

# %%
df.loc[:, 'rating'] = df.loc[:, 'rating'].div(2)

# %%
df
# Out:
#                                name     locality region postal_code  \
# 5234            Sequoyah State Park      Hulbert     OK       74441
# 1045                 China Peak DGC    Lakeshore     CA       93634
# 2812        Jamestown Reservoir DGC    Jamestown     ND       58401
# 5929          The Rock at Stonewall    Germanton     NC       27019
# 4881                  Riverbend DGC     Estacada     OR       97023
# ...                             ...          ...    ...         ...
# 6543                  Whitefish DGC    Whitefish     MT       59937
# 210   Augusta Disc Golf - Dragonfly      Augusta     ME       04330
# 6579           Wildflower Micro DGC   Cedar Park     TX       78613
# 2130       Gehringer Park Rec. Club      Concord     CA       94519
# 3064      L.L. Stub Stewart SP - PP       Buxton     OR       97064
#
#        latitude   longitude dgcr_id  year_established      tee_type  \
# 5234  35.896629  -95.242179    5795              2012         Grass
# 1045  37.236316 -119.158487    6299              2013        Rubber
# 2812  46.945319  -98.705633     575              2007      Concrete
# 5929  36.275930  -80.245988    8724              2016         Grass
# 4881  45.306640 -122.366399     416              1996      Concrete
# ...         ...         ...     ...               ...           ...
# 6543  48.390634 -114.345035   10746              2018          Dirt
# 210   44.294571  -69.768516    7681              2015  Patio Blocks
# 6579  30.465624  -97.844322    9712              2018        Rubber
# 2130  37.985154 -121.993522    8040              2015        Rubber
# 3064  45.739050 -123.199461    7605              2008         Brick
#
#           basket_type  ...  length  hours_to_play  multiple_layouts  hills  \
# 5234  Re-Tire Model A  ...   16400           7.14              True      2
# 1045       DISCatcher  ...   12962           5.84             False      2
# 2812       DISCatcher  ...   12666           5.73              True      1
# 5929  Dynamic Veteran  ...   12476           5.66              True      2
# 4881       DISCatcher  ...   12333           5.60              True      1
# ...               ...  ...     ...            ...               ...    ...
# 6543           Basket  ...     486           1.12             False      0
# 210        DISCatcher  ...     467           1.11             False      1
# 6579           Mach 5  ...     455           1.11             False      0
# 2130       DISCatcher  ...     427           1.10              True      0
# 3064       DISCatcher  ...     389           1.08             False      1
#
#       woods  par   sse  difficulty  rating  rating_count
# 5234      0   73  46.6   -1.466667   2.375             2
# 1045      1   84  92.7    0.322222   2.250             8
# 2812      0   82  70.3   -0.487500   2.215             7
# 5929      0   70  69.1   -0.050000   1.980            13
# 4881      1   89  81.3   -0.285185   2.310            75
# ...     ...  ...   ...         ...     ...           ...
# 6543      1   29  24.0   -0.555556   1.750             1
# 210       0   18  13.9   -0.455556   1.625             4
# 6579      0   11   7.5   -0.700000   1.315             4
# 2130      1   12   5.9   -1.525000   0.750             1
# 3064      2    9   4.1   -1.633333   0.875             4
#
# [4538 rows x 21 columns]
